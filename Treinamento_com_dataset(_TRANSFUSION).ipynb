# %% [markdown]
# <a href="https://colab.research.google.com/github/LeandroLeite003/teste/blob/main/Treinamento_com_dataset(_TRANSFUSION).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Carrega o Dataset e define a primeira coluna como a label

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/tmoura/machinelearning/master/transfusion.data"

df = pd.read_csv(url, header=None) # Carregar dataset

columns = len(df.columns)

y = df[0] # extrai a primeira coluna, que é o label
X = df.loc[:,1:columns-1]

df
# Out:
#      0   1   2      3   4
# 0    1   2  50  12500  98
# 1    1   0  13   3250  28
# 2    1   1  16   4000  35
# 3    1   2  20   5000  45
# 4    2   1  24   6000  77
# ..  ..  ..  ..    ...  ..
# 743  2  23   2    500  38
# 744  2  21   2    500  52
# 745  2  23   3    750  62
# 746  2  39   1    250  39
# 747  2  72   1    250  72
#
# [748 rows x 5 columns]

# %% [markdown]
# Analisando as informações do dataset

# %%
df.info()

df.shape

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       748 non-null    int64
#  1   1       748 non-null    int64
#  2   2       748 non-null    int64
#  3   3       748 non-null    int64
#  4   4       748 non-null    int64
# dtypes: int64(5)
# memory usage: 29.3 KB
#                 0           1           2             3           4
# count  748.000000  748.000000  748.000000    748.000000  748.000000
# mean     1.762032    9.506684    5.514706   1378.676471   34.282086
# std      0.426124    8.095396    5.839307   1459.826781   24.376714
# min      1.000000    0.000000    1.000000    250.000000    2.000000
# 25%      2.000000    2.750000    2.000000    500.000000   16.000000
# 50%      2.000000    7.000000    4.000000   1000.000000   28.000000
# 75%      2.000000   14.000000    7.000000   1750.000000   50.000000
# ...

# %% [markdown]
# Normaliza os valores das colunas 1, 2, 3 e 4 em valores entre 0 e 1

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

df[1] = MinMaxScaler().fit_transform(np.array(df[1]).reshape(-1,1))
df[2] = MinMaxScaler().fit_transform(np.array(df[2]).reshape(-1,1))
df[3] = MinMaxScaler().fit_transform(np.array(df[3]).reshape(-1,1))
df[4] = MinMaxScaler().fit_transform(np.array(df[4]).reshape(-1,1))

df
# Out:
#      0         1         2         3         4
# 0    1  0.027027  1.000000  1.000000  1.000000
# 1    1  0.000000  0.244898  0.244898  0.270833
# 2    1  0.013514  0.306122  0.306122  0.343750
# 3    1  0.027027  0.387755  0.387755  0.447917
# 4    2  0.013514  0.469388  0.469388  0.781250
# ..  ..       ...       ...       ...       ...
# 743  2  0.310811  0.020408  0.020408  0.375000
# 744  2  0.283784  0.020408  0.020408  0.520833
# 745  2  0.310811  0.040816  0.040816  0.625000
# 746  2  0.527027  0.000000  0.000000  0.385417
# 747  2  0.972973  0.000000  0.000000  0.729167
#
# [748 rows x 5 columns]

# %% [markdown]
# Separa dados para treinamento e teste

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None, stratify=y) # 80% treino e 20% teste

# %% [markdown]
# Treina os Modelos

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

model1 = DecisionTreeClassifier(criterion="gini")
model2 = DecisionTreeClassifier(criterion="entropy", max_depth=None)
model3 = KNeighborsClassifier(n_neighbors=7, metric='minkowski', algorithm='auto')
model4 = KNeighborsClassifier(n_neighbors=5, metric='euclidean', algorithm='brute')

model1.fit(X_train, y_train)
model2.fit(X_train, y_train)
model3.fit(X_train, y_train)
model4.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='brute', metric='euclidean')

# %% [markdown]
# Mede o Desempenho

# %%
from sklearn import metrics

result1 = model1.predict(X_test)
result2 = model2.predict(X_test)
result3 = model3.predict(X_test)
result4 = model4.predict(X_test)

acc1 = metrics.accuracy_score(result1, y_test)
show1 = round(acc1 * 100)
print("{}%".format(show1))

acc2 = metrics.accuracy_score(result2, y_test)
show2 = round(acc2 * 100)
print("{}%".format(show2))

acc3 = metrics.accuracy_score(result3, y_test)
show3 = round(acc3 * 100)
print("{}%".format(show3))

acc4 = metrics.accuracy_score(result4, y_test)
show4 = round(acc4 * 100)
print("{}%".format(show4))
# Out:
# 76%
# 74%
# 71%
# 75%
